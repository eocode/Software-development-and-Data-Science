# %% [markdown]
# ## Trabajo con archivos de texto plano

# %%
'Hola {}'.format('bla bla bla bla')
# Out:
# 'Hola bla bla bla bla'

# %%
# !mkdir db
# Out:
# Ya existe el subdirectorio o el archivo db.

# %%
dir = '/db/{}'.format('test.xls')
dir
# Out:
# '/db/test.xls'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %%
import numpy as np
data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]
}
data
# Out:
# {'edad': [10, 9, 13, 14, 12, 11, 12],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9]}

# %%
# Convertimos a un dataframe
df = pd.DataFrame(data)
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir = './db/{}'.format('test.csv')
dir
# Out:
# './db/test.csv'

# %%
# Pasamos el dataframe a un csv
df.to_csv(dir, index=False)

# %%
df_read = pd.read_csv(dir)
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
# Podemos almacenar la información de distintas formas
df.to_csv(dir, sep='|', index=False)

# %%
df_read = pd.read_csv(dir, sep='|')
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %% [markdown]
# ## Conexión a bases de datos SQL

# %%
# !pip install wheel
# Out:
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (0.34.2)

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\programdata\anaconda3\lib\site-packages (2.8.5)

# %%
import pandas as pd
import psycopg2

# %%
conn_sql = psycopg2.connect(user = "elias",
                            password = "qwerty",
                            host = "localhost",
                            port = "5432",
                            database = "Movies")

# %%
query_sql = '''
SELECT * FROM peliculas
'''

# %%
df = pd.read_sql(query_sql, conn_sql)
df.head(5)
# Out:
#    pelicula_id               titulo  \
# 0           56  Barefoot Manchurian
# 1           57           Basic Easy
# 2           58  Beach Heartbreakers
# 3           59       Bear Graceland
# 4           60      Beast Hunchback
#
#                                          descripción  anio_publicacion  \
# 0  A Intrepid Story of a Cat And a Student who mu...              2006
# 1  A Stunning Epistle of a Man And a Husband who ...              2006
# 2  A Fateful Display of a Womanizer And a Mad Sci...              2006
# 3  A Astounding Saga of a Dog And a Boy who must ...              2006
# 4  A Awe-Inspiring Epistle of a Student And a Squ...              2006
#
#    lenguaje_id  duracion_renta  precio_renta  duracion  costo_reemplazo  \
# 0            1               6          2.99       129            15.99
# 1            1               4          2.99        90            18.99
# 2            1               6          2.99       122            16.99
# 3            1               4          2.99       160            20.99
# 4            1               3          4.99        89            22.99
#
#   clasificacion    ultima_actualizacion           caracteristicas_especiales  \
# 0             G 2013-05-26 14:50:58.951             [Trailers, Commentaries]
# 1         PG-13 2013-05-26 14:50:58.951                     [Deleted Scenes]
# 2             G 2013-05-26 14:50:58.951  [Deleted Scenes, Behind the Scenes]
# 3             R 2013-05-26 14:50:58.951                     [Deleted Scenes]
# 4             R 2013-05-26 14:50:58.951  [Deleted Scenes, Behind the Scenes]
#
#                                        textocompleto
# 0  'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...
# 1  'basic':1 'boat':21 'easi':2 'epistl':5 'husba...
# 2  'beach':1 'display':5 'fate':4 'georgia':21 'h...
# 3  'astound':4 'bear':1 'boy':11 'dog':8 'first':...
# 4  'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...

# %% [markdown]
# ## Usando SQL Alchemy

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (1.3.13)

# %%
import pandas as pd
import sqlalchemy as sql
database_type = 'postgresql'

# %%
user = 'elias'
password = 'qwerty'
host = 'localhost:5432'
database = 'Movies'

conn_string = '{}://{}:{}@{}/{}'.format(
database_type, user, password, host, database)

sql_conn = sql.create_engine(conn_string)
sql_conn
# Out:
# Engine(postgresql://elias:***@localhost:5432/Movies)

# %%
query_sql = '''
SELECT * FROM peliculas
'''

# %%
df = pd.read_sql(query_sql, sql_conn)
df.head(5)
# Out:
#    pelicula_id               titulo  \
# 0           56  Barefoot Manchurian
# 1           57           Basic Easy
# 2           58  Beach Heartbreakers
# 3           59       Bear Graceland
# 4           60      Beast Hunchback
#
#                                          descripción  anio_publicacion  \
# 0  A Intrepid Story of a Cat And a Student who mu...              2006
# 1  A Stunning Epistle of a Man And a Husband who ...              2006
# 2  A Fateful Display of a Womanizer And a Mad Sci...              2006
# 3  A Astounding Saga of a Dog And a Boy who must ...              2006
# 4  A Awe-Inspiring Epistle of a Student And a Squ...              2006
#
#    lenguaje_id  duracion_renta  precio_renta  duracion  costo_reemplazo  \
# 0            1               6          2.99       129            15.99
# 1            1               4          2.99        90            18.99
# 2            1               6          2.99       122            16.99
# 3            1               4          2.99       160            20.99
# 4            1               3          4.99        89            22.99
#
#   clasificacion    ultima_actualizacion           caracteristicas_especiales  \
# 0             G 2013-05-26 14:50:58.951             [Trailers, Commentaries]
# 1         PG-13 2013-05-26 14:50:58.951                     [Deleted Scenes]
# 2             G 2013-05-26 14:50:58.951  [Deleted Scenes, Behind the Scenes]
# 3             R 2013-05-26 14:50:58.951                     [Deleted Scenes]
# 4             R 2013-05-26 14:50:58.951  [Deleted Scenes, Behind the Scenes]
#
#                                        textocompleto
# 0  'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...
# 1  'basic':1 'boat':21 'easi':2 'epistl':5 'husba...
# 2  'beach':1 'display':5 'fate':4 'georgia':21 'h...
# 3  'astound':4 'bear':1 'boy':11 'dog':8 'first':...
# 4  'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...

# %% [markdown]
# ## Otros formatos de archivos

# %%
dir = './db/{}'.format('test.xlsx')
dir
# Out:
# './db/test.xlsx'

# %%
df.to_excel(dir, index=False, sheet_name='Hoja uno')

# %%
pd.read_excel(dir)
# Out:
#      pelicula_id                titulo  \
# 0             56   Barefoot Manchurian
# 1             57            Basic Easy
# 2             58   Beach Heartbreakers
# 3             59        Bear Graceland
# 4             60       Beast Hunchback
# ..           ...                   ...
# 995           52  Ballroom Mockingbird
# 996           53             Bang Kwai
# 997           54      Banger Pinocchio
# 998           55  Barbarella Streetcar
# 999            1      Academy Dinosaur
#
#                                            descripción  anio_publicacion  \
# 0    A Intrepid Story of a Cat And a Student who mu...              2006
# 1    A Stunning Epistle of a Man And a Husband who ...              2006
# 2    A Fateful Display of a Womanizer And a Mad Sci...              2006
# 3    A Astounding Saga of a Dog And a Boy who must ...              2006
# 4    A Awe-Inspiring Epistle of a Student And a Squ...              2006
# ..                                                 ...               ...
# 995  A Thrilling Documentary of a Composer And a Mo...              2006
# 996  A Epic Drama of a Madman And a Cat who must Fa...              2006
# 997  A Awe-Inspiring Drama of a Car And a Pastry Ch...              2006
# 998  A Awe-Inspiring Story of a Feminist And a Cat ...              2006
# 999  A Epic Drama of a Feminist And a Mad Scientist...              2006
#
#      lenguaje_id  duracion_renta  precio_renta  duracion  costo_reemplazo  \
# 0              1               6          2.99       129            15.99
# 1              1               4          2.99        90            18.99
# 2              1               6          2.99       122            16.99
# 3              1               4          2.99       160            20.99
# 4              1               3          4.99        89            22.99
# ..           ...             ...           ...       ...              ...
# 995            1               6          0.98       173            29.99
# 996            1               5          2.98        87            25.99
# 997            1               5          0.98       113            15.99
# 998            1               6          2.98        65            27.99
# 999            1               6          5.99        86            20.99
#
#     clasificacion    ultima_actualizacion  \
# 0               G 2013-05-26 14:50:58.951
# 1           PG-13 2013-05-26 14:50:58.951
# 2               G 2013-05-26 14:50:58.951
# 3               R 2013-05-26 14:50:58.951
# 4               R 2013-05-26 14:50:58.951
# ..            ...                     ...
# 995             G 2019-12-03 23:04:19.601
# 996         NC-17 2019-12-03 23:04:19.601
# 997             R 2019-12-03 23:04:19.601
# 998             G 2019-12-03 23:04:19.601
# 999            PG 2020-05-12 16:35:44.686
#
#                             caracteristicas_especiales  \
# 0                         ['Trailers', 'Commentaries']
# 1                                   ['Deleted Scenes']
# 2              ['Deleted Scenes', 'Behind the Scenes']
# 3                                   ['Deleted Scenes']
# 4              ['Deleted Scenes', 'Behind the Scenes']
# ..                                                 ...
# 995                 ['Commentaries', 'Deleted Scenes']
# 996  ['Commentaries', 'Deleted Scenes', 'Behind the...
# 997     ['Trailers', 'Commentaries', 'Deleted Scenes']
# 998                              ['Behind the Scenes']
# 999            ['Deleted Scenes', 'Behind the Scenes']
#
#                                          textocompleto
# 0    'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...
# 1    'basic':1 'boat':21 'easi':2 'epistl':5 'husba...
# 2    'beach':1 'display':5 'fate':4 'georgia':21 'h...
# 3    'astound':4 'bear':1 'boy':11 'dog':8 'first':...
# 4    'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...
# ..                                                 ...
# 995  'ballroom':1 'california':18 'compos':8 'docum...
# 996  'abandon':20 'amus':21 'bang':1 'cat':11 'dram...
# 997  'awe':5 'awe-inspir':4 'banger':1 'car':10 'ch...
# 998  'awe':5 'awe-inspir':4 'barbarella':1 'cat':13...
# 999  'academi':1 'battl':15 'canadian':20 'dinosaur...
#
# [1000 rows x 13 columns]

# %%
dir = './db/{}'.format('test.json')
dir
# Out:
# './db/test.json'

# %%
df.to_json(dir)

# %%
pd.read_json(dir)
# Out:
#      pelicula_id                titulo  \
# 0             56   Barefoot Manchurian
# 1             57            Basic Easy
# 2             58   Beach Heartbreakers
# 3             59        Bear Graceland
# 4             60       Beast Hunchback
# ..           ...                   ...
# 995           52  Ballroom Mockingbird
# 996           53             Bang Kwai
# 997           54      Banger Pinocchio
# 998           55  Barbarella Streetcar
# 999            1      Academy Dinosaur
#
#                                            descripción  anio_publicacion  \
# 0    A Intrepid Story of a Cat And a Student who mu...              2006
# 1    A Stunning Epistle of a Man And a Husband who ...              2006
# 2    A Fateful Display of a Womanizer And a Mad Sci...              2006
# 3    A Astounding Saga of a Dog And a Boy who must ...              2006
# 4    A Awe-Inspiring Epistle of a Student And a Squ...              2006
# ..                                                 ...               ...
# 995  A Thrilling Documentary of a Composer And a Mo...              2006
# 996  A Epic Drama of a Madman And a Cat who must Fa...              2006
# 997  A Awe-Inspiring Drama of a Car And a Pastry Ch...              2006
# 998  A Awe-Inspiring Story of a Feminist And a Cat ...              2006
# 999  A Epic Drama of a Feminist And a Mad Scientist...              2006
#
#      lenguaje_id  duracion_renta  precio_renta  duracion  costo_reemplazo  \
# 0              1               6          2.99       129            15.99
# 1              1               4          2.99        90            18.99
# 2              1               6          2.99       122            16.99
# 3              1               4          2.99       160            20.99
# 4              1               3          4.99        89            22.99
# ..           ...             ...           ...       ...              ...
# 995            1               6          0.98       173            29.99
# 996            1               5          2.98        87            25.99
# 997            1               5          0.98       113            15.99
# 998            1               6          2.98        65            27.99
# 999            1               6          5.99        86            20.99
#
#     clasificacion  ultima_actualizacion  \
# 0               G         1369579858951
# 1           PG-13         1369579858951
# 2               G         1369579858951
# 3               R         1369579858951
# 4               R         1369579858951
# ..            ...                   ...
# 995             G         1575414259601
# 996         NC-17         1575414259601
# 997             R         1575414259601
# 998             G         1575414259601
# 999            PG         1589301344685
#
#                             caracteristicas_especiales  \
# 0                             [Trailers, Commentaries]
# 1                                     [Deleted Scenes]
# 2                  [Deleted Scenes, Behind the Scenes]
# 3                                     [Deleted Scenes]
# 4                  [Deleted Scenes, Behind the Scenes]
# ..                                                 ...
# 995                     [Commentaries, Deleted Scenes]
# 996  [Commentaries, Deleted Scenes, Behind the Scenes]
# 997           [Trailers, Commentaries, Deleted Scenes]
# 998                                [Behind the Scenes]
# 999                [Deleted Scenes, Behind the Scenes]
#
#                                          textocompleto
# 0    'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...
# 1    'basic':1 'boat':21 'easi':2 'epistl':5 'husba...
# 2    'beach':1 'display':5 'fate':4 'georgia':21 'h...
# 3    'astound':4 'bear':1 'boy':11 'dog':8 'first':...
# 4    'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...
# ..                                                 ...
# 995  'ballroom':1 'california':18 'compos':8 'docum...
# 996  'abandon':20 'amus':21 'bang':1 'cat':11 'dram...
# 997  'awe':5 'awe-inspir':4 'banger':1 'car':10 'ch...
# 998  'awe':5 'awe-inspir':4 'barbarella':1 'cat':13...
# 999  'academi':1 'battl':15 'canadian':20 'dinosaur...
#
# [1000 rows x 13 columns]

# %%
dir = './db/{}'.format('test.pkl')
dir
# Out:
# './db/test.pkl'

# %%
df.to_pickle(dir)

# %%
pd.read_pickle(dir)
# Out:
#      pelicula_id                titulo  \
# 0             56   Barefoot Manchurian
# 1             57            Basic Easy
# 2             58   Beach Heartbreakers
# 3             59        Bear Graceland
# 4             60       Beast Hunchback
# ..           ...                   ...
# 995           52  Ballroom Mockingbird
# 996           53             Bang Kwai
# 997           54      Banger Pinocchio
# 998           55  Barbarella Streetcar
# 999            1      Academy Dinosaur
#
#                                            descripción  anio_publicacion  \
# 0    A Intrepid Story of a Cat And a Student who mu...              2006
# 1    A Stunning Epistle of a Man And a Husband who ...              2006
# 2    A Fateful Display of a Womanizer And a Mad Sci...              2006
# 3    A Astounding Saga of a Dog And a Boy who must ...              2006
# 4    A Awe-Inspiring Epistle of a Student And a Squ...              2006
# ..                                                 ...               ...
# 995  A Thrilling Documentary of a Composer And a Mo...              2006
# 996  A Epic Drama of a Madman And a Cat who must Fa...              2006
# 997  A Awe-Inspiring Drama of a Car And a Pastry Ch...              2006
# 998  A Awe-Inspiring Story of a Feminist And a Cat ...              2006
# 999  A Epic Drama of a Feminist And a Mad Scientist...              2006
#
#      lenguaje_id  duracion_renta  precio_renta  duracion  costo_reemplazo  \
# 0              1               6          2.99       129            15.99
# 1              1               4          2.99        90            18.99
# 2              1               6          2.99       122            16.99
# 3              1               4          2.99       160            20.99
# 4              1               3          4.99        89            22.99
# ..           ...             ...           ...       ...              ...
# 995            1               6          0.98       173            29.99
# 996            1               5          2.98        87            25.99
# 997            1               5          0.98       113            15.99
# 998            1               6          2.98        65            27.99
# 999            1               6          5.99        86            20.99
#
#     clasificacion       ultima_actualizacion  \
# 0               G 2013-05-26 14:50:58.951000
# 1           PG-13 2013-05-26 14:50:58.951000
# 2               G 2013-05-26 14:50:58.951000
# 3               R 2013-05-26 14:50:58.951000
# 4               R 2013-05-26 14:50:58.951000
# ..            ...                        ...
# 995             G 2019-12-03 23:04:19.601194
# 996         NC-17 2019-12-03 23:04:19.601194
# 997             R 2019-12-03 23:04:19.601194
# 998             G 2019-12-03 23:04:19.601194
# 999            PG 2020-05-12 16:35:44.685663
#
#                             caracteristicas_especiales  \
# 0                             [Trailers, Commentaries]
# 1                                     [Deleted Scenes]
# 2                  [Deleted Scenes, Behind the Scenes]
# 3                                     [Deleted Scenes]
# 4                  [Deleted Scenes, Behind the Scenes]
# ..                                                 ...
# 995                     [Commentaries, Deleted Scenes]
# 996  [Commentaries, Deleted Scenes, Behind the Scenes]
# 997           [Trailers, Commentaries, Deleted Scenes]
# 998                                [Behind the Scenes]
# 999                [Deleted Scenes, Behind the Scenes]
#
#                                          textocompleto
# 0    'abandon':19 'amus':20 'barefoot':1 'cat':8 'g...
# 1    'basic':1 'boat':21 'easi':2 'epistl':5 'husba...
# 2    'beach':1 'display':5 'fate':4 'georgia':21 'h...
# 3    'astound':4 'bear':1 'boy':11 'dog':8 'first':...
# 4    'ancient':20 'awe':5 'awe-inspir':4 'beast':1 ...
# ..                                                 ...
# 995  'ballroom':1 'california':18 'compos':8 'docum...
# 996  'abandon':20 'amus':21 'bang':1 'cat':11 'dram...
# 997  'awe':5 'awe-inspir':4 'banger':1 'car':10 'ch...
# 998  'awe':5 'awe-inspir':4 'barbarella':1 'cat':13...
# 999  'academi':1 'battl':15 'canadian':20 'dinosaur...
#
# [1000 rows x 13 columns]
