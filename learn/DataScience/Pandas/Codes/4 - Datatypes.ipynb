# %% [markdown]
# ## Datatypes

# %%
import pandas as pd
dir = './db/Meteorite_Landings.csv'

# %%
df = pd.read_csv(dir)
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4 107,000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite   1,914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year  reclat  reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM    50.8      6.1     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM    56.2     10.2  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM    54.2   -113.0    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM    16.9    -99.9     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM   -33.2    -65.0   (-33.16667, -64.95)

# %%
# Datos aleatorios
df.sample(5)
# Out:
#                          name     id nametype      recclass  mass (g)   fall  \
# 17476                  Landor  12458    Valid          Iron   9,000.0  Found
# 8170               Dhofar 809   7555    Valid            L4      25.4  Found
# 45095           Yamato 983366  39988    Valid  Eucrite-unbr     138.9  Found
# 14704  Grove Mountains 023310  50164    Valid            H6       0.5  Found
# 1125                Acfer 009     19    Valid            L6     127.0  Found
#
#                          year  reclat  reclong          GeoLocation
# 17476  01/01/1931 12:00:00 AM   -25.7    117.0   (-25.66667, 117.0)
# 8170   01/01/2001 12:00:00 AM    18.6     54.1  (18.5645, 54.09627)
# 45095  01/01/1998 12:00:00 AM     0.0      0.0           (0.0, 0.0)
# 14704  01/01/2003 12:00:00 AM   -72.8     75.3  (-72.775, 75.33889)
# 1125   01/01/1989 12:00:00 AM    27.7      4.1  (27.73333, 4.08333)

# %%
# Forma de la tabla
df.shape
# Out:
# (45716, 10)

# %%
# Tamaño de los datos filas * columnas
df.size
# Out:
# 457160

# %%
# Descripción de las variables númericas
df.describe()
# Out:
#             id     mass (g)   reclat  reclong
# count 45,716.0     45,585.0 38,401.0 38,401.0
# mean  26,889.7     13,278.1    -39.1     61.1
# std   16,860.7    574,988.9     46.4     80.6
# min        1.0          0.0    -87.4   -165.4
# 25%   12,688.8          7.2    -76.7      0.0
# 50%   24,261.5         32.6    -71.5     35.7
# 75%   40,656.8        202.6      0.0    157.2
# max   57,458.0 60,000,000.0     81.2    354.5

# %%
# Personaliza la salida
pd.options.display.float_format = '{:,.1f}'.format

# %%
# Inclue todas las variables
df.describe(include='all')
# Out:
#              name       id nametype recclass     mass (g)   fall  \
# count       45716 45,716.0    45716    45716     45,585.0  45716
# unique      45716      nan        2      466          nan      2
# top     Acfer 198      nan    Valid       L6          nan  Found
# freq            1      nan    45641     8285          nan  44609
# mean          NaN 26,889.7      NaN      NaN     13,278.1    NaN
# std           NaN 16,860.7      NaN      NaN    574,988.9    NaN
# min           NaN      1.0      NaN      NaN          0.0    NaN
# 25%           NaN 12,688.8      NaN      NaN          7.2    NaN
# 50%           NaN 24,261.5      NaN      NaN         32.6    NaN
# 75%           NaN 40,656.8      NaN      NaN        202.6    NaN
# max           NaN 57,458.0      NaN      NaN 60,000,000.0    NaN
#
#                           year   reclat  reclong GeoLocation
# count                    45425 38,401.0 38,401.0       38401
# unique                     266      nan      nan       17100
# ...

# %%
# Conocer estructura de los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df.convert_dtypes().dtypes
# Out:
# name            string
# id               Int64
# nametype        string
# recclass        string
# mass (g)       float64
# fall            string
# year            string
# reclat         float64
# reclong        float64
# GeoLocation     string
# dtype: object

# %%
# Datos únicos para identificar variables categoricas
df.nunique()
# Out:
# name           45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12576
# fall               2
# year             266
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
df[['fall','nametype']]
# Out:
#         fall nametype
# 0       Fell    Valid
# 1       Fell    Valid
# 2       Fell    Valid
# 3       Fell    Valid
# 4       Fell    Valid
# ...      ...      ...
# 45711  Found    Valid
# 45712  Found    Valid
# 45713  Found    Valid
# 45714  Found    Valid
# 45715  Found    Valid
#
# [45716 rows x 2 columns]

# %%
# Aplicar el tipo de dato a estas variables
df[['fall','nametype']] = df[['fall','nametype']].astype('category')

# %%
df.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year             object
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
# Podemos ver los valores que componen a la categoría
df['fall'].unique()
# Out:
# [Fell, Found]
# Categories (2, object): [Fell, Found]

# %%
df['fall'].value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
# Convertir una variable tipo texto a númerico
pd.get_dummies(df['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
df['ones'] = 1
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year  reclat  reclong             GeoLocation  ones
# ...

# %%
df[['fell','found']] = pd.get_dummies(df['fall'])
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year  reclat  reclong             GeoLocation  ones  \
# ...

# %%
df['year']
# Out:
# 0        01/01/1880 12:00:00 AM
# 1        01/01/1951 12:00:00 AM
# 2        01/01/1952 12:00:00 AM
# 3        01/01/1976 12:00:00 AM
# 4        01/01/1902 12:00:00 AM
#                   ...
# 45711    01/01/1990 12:00:00 AM
# 45712    01/01/1999 12:00:00 AM
# 45713    01/01/1939 12:00:00 AM
# 45714    01/01/2003 12:00:00 AM
# 45715    01/01/1976 12:00:00 AM
# Name: year, Length: 45716, dtype: object

# %%
pd.to_datetime(
    df['year'],
    errors = 'coerce',
    format = '%m/%d/%Y %H:%M:%S %p'
)
# Out:
# 0       1880-01-01 12:00:00
# 1       1951-01-01 12:00:00
# 2       1952-01-01 12:00:00
# 3       1976-01-01 12:00:00
# 4       1902-01-01 12:00:00
#                 ...
# 45711   1990-01-01 12:00:00
# 45712   1999-01-01 12:00:00
# 45713   1939-01-01 12:00:00
# 45714   2003-01-01 12:00:00
# 45715   1976-01-01 12:00:00
# Name: year, Length: 45716, dtype: datetime64[ns]

# %%
df['year'] = pd.to_datetime(
    df['year'],
    errors = 'coerce',
    format = '%m/%d/%Y %H:%M:%S %p'
)

# %%
df.convert_dtypes().dtypes
# Out:
# name                   string
# id                      Int64
# nametype             category
# recclass               string
# mass (g)              float64
# fall                 category
# year           datetime64[ns]
# reclat                float64
# reclong               float64
# GeoLocation            string
# ones                    Int64
# fell                    UInt8
# found                   UInt8
# dtype: object

# %%
df.rename(columns={'mass (g)':'mass'}, inplace=True)

# %%
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  ones  \
# ...

# %%
df.drop(['ones'], axis=1, inplace=True)

# %%
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
df.drop(columns=['recclass','id'], index=[0,2,4,6]).head(10)
# Out:
#                 name nametype     mass  fall                year  reclat  \
# 1             Aarhus    Valid    720.0  Fell 1951-01-01 12:00:00    56.2
# 3           Acapulco    Valid  1,914.0  Fell 1976-01-01 12:00:00    16.9
# 5           Adhi Kot    Valid  4,239.0  Fell 1919-01-01 12:00:00    32.1
# 7               Agen    Valid 30,000.0  Fell 1814-01-01 12:00:00    44.2
# 8             Aguada    Valid  1,620.0  Fell 1930-01-01 12:00:00   -31.6
# 9      Aguila Blanca    Valid  1,440.0  Fell 1920-01-01 12:00:00   -30.9
# 10  Aioun el Atrouss    Valid  1,000.0  Fell 1974-01-01 12:00:00    16.4
# 11               Aïr    Valid 24,000.0  Fell 1925-01-01 12:00:00    19.1
# 12   Aire-sur-la-Lys    Valid      nan  Fell 1769-01-01 12:00:00    50.7
# 13             Akaba    Valid    779.0  Fell 1949-01-01 12:00:00    29.5
#
#     reclong           GeoLocation  fell  found
# 1      10.2  (56.18333, 10.23333)     1      0
# 3     -99.9     (16.88333, -99.9)     1      0
# ...

# %%
# Copia los datos no la referencia
df2 = df.copy(deep=True)

# %%
df2.drop(['id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall                year  \
# 0    Aachen    1    Valid           L5      21.0  Fell 1880-01-01 12:00:00
# 1    Aarhus    2    Valid           H6     720.0  Fell 1951-01-01 12:00:00
# 2      Abee    6    Valid          EH4 107,000.0  Fell 1952-01-01 12:00:00
# 3  Acapulco   10    Valid  Acapulcoite   1,914.0  Fell 1976-01-01 12:00:00
# 4   Achiras  370    Valid           L6     780.0  Fell 1902-01-01 12:00:00
#
#    reclat  reclong           GeoLocation  fell  found
# 0    50.8      6.1     (50.775, 6.08333)     1      0
# 1    56.2     10.2  (56.18333, 10.23333)     1      0
# 2    54.2   -113.0    (54.21667, -113.0)     1      0
# 3    16.9    -99.9     (16.88333, -99.9)     1      0
# 4   -33.2    -65.0   (-33.16667, -64.95)     1      0

# %%
df2.head()
# Out:
#        name nametype     recclass      mass  fall                year  reclat  \
# 0    Aachen    Valid           L5      21.0  Fell 1880-01-01 12:00:00    50.8
# 1    Aarhus    Valid           H6     720.0  Fell 1951-01-01 12:00:00    56.2
# 2      Abee    Valid          EH4 107,000.0  Fell 1952-01-01 12:00:00    54.2
# 3  Acapulco    Valid  Acapulcoite   1,914.0  Fell 1976-01-01 12:00:00    16.9
# 4   Achiras    Valid           L6     780.0  Fell 1902-01-01 12:00:00   -33.2
#
#    reclong           GeoLocation  fell  found
# 0      6.1     (50.775, 6.08333)     1      0
# 1     10.2  (56.18333, 10.23333)     1      0
# 2   -113.0    (54.21667, -113.0)     1      0
# 3    -99.9     (16.88333, -99.9)     1      0
# 4    -65.0   (-33.16667, -64.95)     1      0

# %%
# Ver valores nulos
df.isna().any()
# Out:
# name           False
# id             False
# nametype       False
# recclass       False
# mass            True
# fall           False
# year            True
# reclat          True
# reclong         True
# GeoLocation     True
# fell           False
# found          False
# dtype: bool

# %%
df['mass'].isna().value_counts()
# Out:
# False    45585
# True       131
# Name: mass, dtype: int64

# %%
# Para borrar los valores nulos
df['mass'] = df['mass'].dropna()
df['mass']
# Out:
# 0            21.0
# 1           720.0
# 2       107,000.0
# 3         1,914.0
# 4           780.0
#            ...
# 45711       172.0
# 45712        46.0
# 45713         3.3
# 45714     2,167.0
# 45715       200.0
# Name: mass, Length: 45716, dtype: float64

# %%
df.dropna()
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...
