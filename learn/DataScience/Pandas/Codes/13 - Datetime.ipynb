# %% [markdown]
# ## Datetime

# %%
import pandas as pd

# %%
df = pd.read_csv('./db/covid_19_data.csv')
df
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 24446  24447      05/13/2020        Wyoming              US
# 24447  24448      05/13/2020       Xinjiang  Mainland China
# 24448  24449      05/13/2020          Yukon          Canada
# 24449  24450      05/13/2020         Yunnan  Mainland China
# 24450  24451      05/13/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 24446  2020-05-14 03:32:28      688.0     7.0        0.0
# 24447  2020-05-14 03:32:28       76.0     3.0       73.0
# 24448  2020-05-14 03:32:28       11.0     0.0        0.0
# 24449  2020-05-14 03:32:28      185.0     2.0      183.0
# 24450  2020-05-14 03:32:28     1268.0     1.0     1267.0
#
# [24451 rows x 8 columns]

# %%
df.sample(10)
# Out:
#          SNo ObservationDate     Province/State  Country/Region  \
# 2161    2162      02/23/2020    New South Wales       Australia
# 7151    7152      03/20/2020                NaN         Andorra
# 20821  20822      05/02/2020              Maine              US
# 1863    1864      02/19/2020    San Antonio, TX              US
# 7764    7765      03/22/2020                NaN     Timor-Leste
# 6210    6211      03/17/2020                NaN          Poland
# 4452    4453      03/09/2020  Carver County, MN              US
# 14589  14590      04/13/2020                NaN          Malawi
# 9958    9959      03/29/2020     Inner Mongolia  Mainland China
# 4551    4552      03/10/2020                NaN       Singapore
#
#                Last Update  Confirmed  Deaths  Recovered
# 2161   2020-02-13T17:53:03        4.0     0.0        4.0
# 7151   2020-03-20T15:13:21       75.0     0.0        1.0
# 20821  2020-05-03 02:32:28     1153.0    56.0        0.0
# 1863   2020-02-13T18:53:02        1.0     0.0        0.0
# 7764           3/8/20 5:31        1.0     0.0        0.0
# 6210   2020-03-17T20:53:02      238.0     5.0       13.0
# 4452   2020-03-09T08:43:02        1.0     0.0        0.0
# 14589  2020-04-13 23:15:42       16.0     2.0        0.0
# 9958           3/8/20 5:31       95.0     1.0       74.0
# 4551   2020-03-10T05:13:07      160.0     0.0       78.0

# %%
df['ObservationDate'] = pd.to_datetime(df['ObservationDate'])

# %%
list(df)
# Out:
# ['SNo',
#  'ObservationDate',
#  'Province/State',
#  'Country/Region',
#  'Last Update',
#  'Confirmed',
#  'Deaths',
#  'Recovered']

# %%
df = df[['ObservationDate',
 'Country/Region',
 'Confirmed',
 'Deaths',
 'Recovered']]
df
# Out:
#       ObservationDate  Country/Region  Confirmed  Deaths  Recovered
# 0          2020-01-22  Mainland China        1.0     0.0        0.0
# 1          2020-01-22  Mainland China       14.0     0.0        0.0
# 2          2020-01-22  Mainland China        6.0     0.0        0.0
# 3          2020-01-22  Mainland China        1.0     0.0        0.0
# 4          2020-01-22  Mainland China        0.0     0.0        0.0
# ...               ...             ...        ...     ...        ...
# 24446      2020-05-13              US      688.0     7.0        0.0
# 24447      2020-05-13  Mainland China       76.0     3.0       73.0
# 24448      2020-05-13          Canada       11.0     0.0        0.0
# 24449      2020-05-13  Mainland China      185.0     2.0      183.0
# 24450      2020-05-13  Mainland China     1268.0     1.0     1267.0
#
# [24451 rows x 5 columns]

# %%
df_time = df.groupby(['ObservationDate']).sum()
df_time.head(5)
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0    17.0       28.0
# 2020-01-23           653.0    18.0       30.0
# 2020-01-24           941.0    26.0       36.0
# 2020-01-25          1438.0    42.0       39.0
# 2020-01-26          2118.0    56.0       52.0

# %%
df1 = df_time['Confirmed'].iloc[10:15]
df1
# Out:
# ObservationDate
# 2020-02-01    12038.0
# 2020-02-02    16787.0
# 2020-02-03    19881.0
# 2020-02-04    23892.0
# 2020-02-05    27636.0
# Name: Confirmed, dtype: float64

# %%
df2 = df_time['Deaths'].iloc[12:17]
df2
# Out:
# ObservationDate
# 2020-02-03    426.0
# 2020-02-04    492.0
# 2020-02-05    564.0
# 2020-02-06    634.0
# 2020-02-07    719.0
# Name: Deaths, dtype: float64

# %%
df1 - df2
# Out:
# ObservationDate
# 2020-02-01        NaN
# 2020-02-02        NaN
# 2020-02-03    19455.0
# 2020-02-04    23400.0
# 2020-02-05    27072.0
# 2020-02-06        NaN
# 2020-02-07        NaN
# dtype: float64

# %%
df_time
# Out:
#                  Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0      17.0       28.0
# 2020-01-23           653.0      18.0       30.0
# 2020-01-24           941.0      26.0       36.0
# 2020-01-25          1438.0      42.0       39.0
# 2020-01-26          2118.0      56.0       52.0
# ...                    ...       ...        ...
# 2020-05-09       4024009.0  279311.0  1375624.0
# 2020-05-10       4101699.0  282709.0  1408980.0
# 2020-05-11       4177504.0  286330.0  1456209.0
# 2020-05-12       4261955.0  291964.0  1493414.0
# 2020-05-13       4347018.0  297197.0  1548547.0
#
# [113 rows x 3 columns]

# %%
df_time.diff()
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22             NaN     NaN        NaN
# 2020-01-23            98.0     1.0        2.0
# 2020-01-24           288.0     8.0        6.0
# 2020-01-25           497.0    16.0        3.0
# 2020-01-26           680.0    14.0       13.0
# ...                    ...     ...        ...
# 2020-05-09         85945.0  4413.0    53574.0
# 2020-05-10         77690.0  3398.0    33356.0
# 2020-05-11         75805.0  3621.0    47229.0
# 2020-05-12         84451.0  5634.0    37205.0
# 2020-05-13         85063.0  5233.0    55133.0
#
# [113 rows x 3 columns]

# %%
df_time.diff().mean()
# Out:
# Confirmed    38807.705357
# Deaths        2653.392857
# Recovered    13826.062500
# dtype: float64

# %%
df_diff = df_time.diff()
df_diff
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22             NaN     NaN        NaN
# 2020-01-23            98.0     1.0        2.0
# 2020-01-24           288.0     8.0        6.0
# 2020-01-25           497.0    16.0        3.0
# 2020-01-26           680.0    14.0       13.0
# ...                    ...     ...        ...
# 2020-05-09         85945.0  4413.0    53574.0
# 2020-05-10         77690.0  3398.0    33356.0
# 2020-05-11         75805.0  3621.0    47229.0
# 2020-05-12         84451.0  5634.0    37205.0
# 2020-05-13         85063.0  5233.0    55133.0
#
# [113 rows x 3 columns]

# %%
df_time.head(1).to_dict()
# Out:
# {'Confirmed': {Timestamp('2020-01-22 00:00:00'): 555.0},
#  'Deaths': {Timestamp('2020-01-22 00:00:00'): 17.0},
#  'Recovered': {Timestamp('2020-01-22 00:00:00'): 28.0}}

# %%
df_diff = df_diff.fillna({'Confirmed': 555.0,
 'Deaths': 17.0,
 'Recovered': 28.0})
df_diff
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0    17.0       28.0
# 2020-01-23            98.0     1.0        2.0
# 2020-01-24           288.0     8.0        6.0
# 2020-01-25           497.0    16.0        3.0
# 2020-01-26           680.0    14.0       13.0
# ...                    ...     ...        ...
# 2020-05-09         85945.0  4413.0    53574.0
# 2020-05-10         77690.0  3398.0    33356.0
# 2020-05-11         75805.0  3621.0    47229.0
# 2020-05-12         84451.0  5634.0    37205.0
# 2020-05-13         85063.0  5233.0    55133.0
#
# [113 rows x 3 columns]

# %%
df_diff.cumsum()
# Out:
#                  Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0      17.0       28.0
# 2020-01-23           653.0      18.0       30.0
# 2020-01-24           941.0      26.0       36.0
# 2020-01-25          1438.0      42.0       39.0
# 2020-01-26          2118.0      56.0       52.0
# ...                    ...       ...        ...
# 2020-05-09       4024009.0  279311.0  1375624.0
# 2020-05-10       4101699.0  282709.0  1408980.0
# 2020-05-11       4177504.0  286330.0  1456209.0
# 2020-05-12       4261955.0  291964.0  1493414.0
# 2020-05-13       4347018.0  297197.0  1548547.0
#
# [113 rows x 3 columns]

# %%
df_diff.resample('7D').sum()
# Out:
#                  Confirmed   Deaths  Recovered
# ObservationDate
# 2020-01-22          5578.0    131.0      107.0
# 2020-01-29         18314.0    361.0      745.0
# 2020-02-05         20911.0    621.0     3831.0
# 2020-02-12         30335.0    894.0     9669.0
# 2020-02-19          5277.0    701.0    13553.0
# 2020-02-26         12429.0    452.0    20324.0
# 2020-03-04         25738.0   1102.0    16175.0
# 2020-03-11         78586.0   3643.0    16436.0
# 2020-03-18        220794.0  10710.0    26859.0
# 2020-03-25        439525.0  23492.0    70329.0
# 2020-04-01        568609.0  39758.0   122026.0
# 2020-04-08        550096.0  44119.0   174207.0
# 2020-04-15        572931.0  50599.0   205558.0
# 2020-04-22        567275.0  40570.0   248839.0
# 2020-04-29        546293.0  40086.0   270174.0
# 2020-05-06        599264.0  34725.0   294582.0
# 2020-05-13         85063.0   5233.0    55133.0

# %%
df_diff.resample('W-Sun').sum()
# Out:
#                  Confirmed   Deaths  Recovered
# ObservationDate
# 2020-01-26          2118.0     56.0       52.0
# 2020-02-02         14669.0    306.0      420.0
# 2020-02-09         23364.0    544.0     2772.0
# 2020-02-16         31075.0    864.0     7621.0
# 2020-02-23          7759.0    699.0    12529.0
# 2020-03-01          9386.0    527.0    19322.0
# 2020-03-08         21464.0    807.0    17979.0
# 2020-03-15         57612.0   2637.0    15339.0
# 2020-03-22        169675.0   8183.0    21209.0
# 2020-03-29        383018.0  19302.0    51833.0
# 2020-04-05        551975.0  35449.0   110936.0
# 2020-04-12        574565.0  44715.0   161710.0
# 2020-04-19        554699.0  50955.0   202181.0
# 2020-04-26        570096.0  41500.0   241830.0
# 2020-05-03        535254.0  40926.0   259503.0
# 2020-05-10        594970.0  35239.0   283744.0
# 2020-05-17        245319.0  14488.0   139567.0

# %%
df_diff.resample('M').sum()
# Out:
#                  Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-31          9925.0     213.0      222.0
# 2020-02-29         76088.0    2728.0    39560.0
# 2020-03-31        771474.0   39166.0   138246.0
# 2020-04-30       2399359.0  191281.0   836725.0
# 2020-05-31       1090172.0   63809.0   533794.0

# %%
df_diff.resample('M').count()
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-31              10      10         10
# 2020-02-29              29      29         29
# 2020-03-31              31      31         31
# 2020-04-30              30      30         30
# 2020-05-31              13      13         13

# %%
df_diff.resample('M').mean()
# Out:
#                     Confirmed       Deaths     Recovered
# ObservationDate
# 2020-01-31         992.500000    21.300000     22.200000
# 2020-02-29        2623.724138    94.068966   1364.137931
# 2020-03-31       24886.258065  1263.419355   4459.548387
# 2020-04-30       79978.633333  6376.033333  27890.833333
# 2020-05-31       83859.384615  4908.384615  41061.076923

# %%
df_diff.resample('12h').sum()
# Out:
#                      Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0    17.0       28.0
# 2020-01-22 12:00:00        0.0     0.0        0.0
# 2020-01-23 00:00:00       98.0     1.0        2.0
# 2020-01-23 12:00:00        0.0     0.0        0.0
# 2020-01-24 00:00:00      288.0     8.0        6.0
# ...                        ...     ...        ...
# 2020-05-11 00:00:00    75805.0  3621.0    47229.0
# 2020-05-11 12:00:00        0.0     0.0        0.0
# 2020-05-12 00:00:00    84451.0  5634.0    37205.0
# 2020-05-12 12:00:00        0.0     0.0        0.0
# 2020-05-13 00:00:00    85063.0  5233.0    55133.0
#
# [225 rows x 3 columns]

# %%
df_diff.resample('12h').mean()
# Out:
#                      Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0    17.0       28.0
# 2020-01-22 12:00:00        NaN     NaN        NaN
# 2020-01-23 00:00:00       98.0     1.0        2.0
# 2020-01-23 12:00:00        NaN     NaN        NaN
# 2020-01-24 00:00:00      288.0     8.0        6.0
# ...                        ...     ...        ...
# 2020-05-11 00:00:00    75805.0  3621.0    47229.0
# 2020-05-11 12:00:00        NaN     NaN        NaN
# 2020-05-12 00:00:00    84451.0  5634.0    37205.0
# 2020-05-12 12:00:00        NaN     NaN        NaN
# 2020-05-13 00:00:00    85063.0  5233.0    55133.0
#
# [225 rows x 3 columns]

# %%
df_cum = df_time.resample('12h').sum(min_count=1)
df_cum
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00        NaN       NaN        NaN
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00        NaN       NaN        NaN
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00        NaN       NaN        NaN
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00        NaN       NaN        NaN
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
df_cum = df_cum.interpolate()
df_cum
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00      604.0      17.5       29.0
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00      797.0      22.0       33.0
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
# Valor siguiente para completar
df_cum.bfill()
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00      604.0      17.5       29.0
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00      797.0      22.0       33.0
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
# Valor anterior para completar
df_cum.ffill()
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00      604.0      17.5       29.0
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00      797.0      22.0       33.0
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
df_cum.fillna(-1000)
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00      604.0      17.5       29.0
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00      797.0      22.0       33.0
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
df_cum.interpolate()
# Out:
#                      Confirmed    Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0
# 2020-01-22 12:00:00      604.0      17.5       29.0
# 2020-01-23 00:00:00      653.0      18.0       30.0
# 2020-01-23 12:00:00      797.0      22.0       33.0
# 2020-01-24 00:00:00      941.0      26.0       36.0
# ...                        ...       ...        ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0
#
# [225 rows x 3 columns]

# %%
df_cum['rate'] = 1 - df_cum['Deaths'] / df_cum['Confirmed']
df_cum
# Out:
#                      Confirmed    Deaths  Recovered      rate
# ObservationDate
# 2020-01-22 00:00:00      555.0      17.0       28.0  0.969369
# 2020-01-22 12:00:00      604.0      17.5       29.0  0.971026
# 2020-01-23 00:00:00      653.0      18.0       30.0  0.972435
# 2020-01-23 12:00:00      797.0      22.0       33.0  0.972396
# 2020-01-24 00:00:00      941.0      26.0       36.0  0.972370
# ...                        ...       ...        ...       ...
# 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0  0.931459
# 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5  0.931477
# 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0  0.931495
# 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5  0.931564
# 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0  0.931632
#
# [225 rows x 4 columns]

# %%
df_cum = df_cum.reset_index()
df_cum
# Out:
#         ObservationDate  Confirmed    Deaths  Recovered      rate
# 0   2020-01-22 00:00:00      555.0      17.0       28.0  0.969369
# 1   2020-01-22 12:00:00      604.0      17.5       29.0  0.971026
# 2   2020-01-23 00:00:00      653.0      18.0       30.0  0.972435
# 3   2020-01-23 12:00:00      797.0      22.0       33.0  0.972396
# 4   2020-01-24 00:00:00      941.0      26.0       36.0  0.972370
# ..                  ...        ...       ...        ...       ...
# 220 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0  0.931459
# 221 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5  0.931477
# 222 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0  0.931495
# 223 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5  0.931564
# 224 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0  0.931632
#
# [225 rows x 5 columns]

# %%
df_cum
# Out:
#         ObservationDate  Confirmed    Deaths  Recovered      rate
# 0   2020-01-22 00:00:00      555.0      17.0       28.0  0.969369
# 1   2020-01-22 12:00:00      604.0      17.5       29.0  0.971026
# 2   2020-01-23 00:00:00      653.0      18.0       30.0  0.972435
# 3   2020-01-23 12:00:00      797.0      22.0       33.0  0.972396
# 4   2020-01-24 00:00:00      941.0      26.0       36.0  0.972370
# ..                  ...        ...       ...        ...       ...
# 220 2020-05-11 00:00:00  4177504.0  286330.0  1456209.0  0.931459
# 221 2020-05-11 12:00:00  4219729.5  289147.0  1474811.5  0.931477
# 222 2020-05-12 00:00:00  4261955.0  291964.0  1493414.0  0.931495
# 223 2020-05-12 12:00:00  4304486.5  294580.5  1520980.5  0.931564
# 224 2020-05-13 00:00:00  4347018.0  297197.0  1548547.0  0.931632
#
# [225 rows x 5 columns]

# %%
df_cum.groupby(pd.Grouper(key='ObservationDate', freq='M'))[['rate']].mean()
# Out:
#                      rate
# ObservationDate
# 2020-01-31       0.974594
# 2020-02-29       0.973562
# 2020-03-31       0.960070
# 2020-04-30       0.936029
# 2020-05-31       0.930202

# %%
sr = df_cum.groupby(pd.Grouper(key='ObservationDate', freq='1D'))['rate'].mean()
sr.plot()

# %%
sr.rolling(window=7).mean().plot()

# %%
sr.plot()
sr.rolling(window=7).mean().plot()
sr.rolling(window=14).mean().plot()

# %%
import numpy as np
sr.rolling(window=14).apply(lambda x: np.std(x)).plot()

# %%
df
# Out:
#       ObservationDate  Country/Region  Confirmed  Deaths  Recovered
# 0          2020-01-22  Mainland China        1.0     0.0        0.0
# 1          2020-01-22  Mainland China       14.0     0.0        0.0
# 2          2020-01-22  Mainland China        6.0     0.0        0.0
# 3          2020-01-22  Mainland China        1.0     0.0        0.0
# 4          2020-01-22  Mainland China        0.0     0.0        0.0
# ...               ...             ...        ...     ...        ...
# 24446      2020-05-13              US      688.0     7.0        0.0
# 24447      2020-05-13  Mainland China       76.0     3.0       73.0
# 24448      2020-05-13          Canada       11.0     0.0        0.0
# 24449      2020-05-13  Mainland China      185.0     2.0      183.0
# 24450      2020-05-13  Mainland China     1268.0     1.0     1267.0
#
# [24451 rows x 5 columns]

# %%
df.groupby(['Country/Region'])['Confirmed'].max().sort_values(ascending=False)
# Out:
# Country/Region
# US                       340661.0
# Russia                   242271.0
# Spain                    236899.0
# UK                       229705.0
# Italy                    222104.0
#                            ...
# North Ireland                 1.0
# Channel Islands               1.0
# Republic of the Congo         1.0
# Gambia, The                   1.0
#  Azerbaijan                   1.0
# Name: Confirmed, Length: 223, dtype: float64

# %%
list(df)
# Out:
# ['ObservationDate', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered']

# %%
df_time = df.groupby(['Country/Region',
           pd.Grouper(key='ObservationDate', freq='1D')]).sum()
df_time
# Out:
#                                                 Confirmed  Deaths  Recovered
# Country/Region                 ObservationDate
#  Azerbaijan                    2020-02-28             1.0     0.0        0.0
# ('St. Martin',)                2020-03-10             2.0     0.0        0.0
# Afghanistan                    2020-02-24             1.0     0.0        0.0
#                                2020-02-25             1.0     0.0        0.0
#                                2020-02-26             1.0     0.0        0.0
# ...                                                   ...     ...        ...
# occupied Palestinian territory 2020-03-12             0.0     0.0        0.0
#                                2020-03-14             0.0     0.0        0.0
#                                2020-03-15             0.0     0.0        0.0
#                                2020-03-16             0.0     0.0        0.0
#                                2020-03-17             0.0     0.0        0.0
#
# [13561 rows x 3 columns]

# %%
df_us = df_time.loc['US']
df_us
# Out:
#                  Confirmed   Deaths  Recovered
# ObservationDate
# 2020-01-22             1.0      0.0        0.0
# 2020-01-23             1.0      0.0        0.0
# 2020-01-24             2.0      0.0        0.0
# 2020-01-25             2.0      0.0        0.0
# 2020-01-26             5.0      0.0        0.0
# ...                    ...      ...        ...
# 2020-05-09       1309550.0  78795.0   212534.0
# 2020-05-10       1329260.0  79526.0   216169.0
# 2020-05-11       1347881.0  80682.0   232733.0
# 2020-05-12       1369574.0  82376.0   230287.0
# 2020-05-13       1390406.0  84119.0   243430.0
#
# [113 rows x 3 columns]

# %%
df_us.plot(figsize = (10,7), title="COVID-19")

# %%
df_mx = df_time.loc['Mexico']
df_mx
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-23             0.0     0.0        0.0
# 2020-02-28             1.0     0.0        0.0
# 2020-02-29             4.0     0.0        0.0
# 2020-03-01             5.0     0.0        0.0
# 2020-03-02             5.0     0.0        0.0
# ...                    ...     ...        ...
# 2020-05-09         33460.0  3353.0    21824.0
# 2020-05-10         35022.0  3465.0    21824.0
# 2020-05-11         36327.0  3573.0    23100.0
# 2020-05-12         38324.0  3926.0    25935.0
# 2020-05-13         40186.0  4220.0    26990.0
#
# [77 rows x 3 columns]

# %%
df_mx.plot(figsize = (10,7), title="COVID-19")

# %%
df_china = df_time.loc['Mainland China']
df_china
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           547.0    17.0       28.0
# 2020-01-23           639.0    18.0       30.0
# 2020-01-24           916.0    26.0       36.0
# 2020-01-25          1399.0    42.0       39.0
# 2020-01-26          2062.0    56.0       49.0
# ...                    ...     ...        ...
# 2020-05-09         82901.0  4633.0    78120.0
# 2020-05-10         82918.0  4633.0    78144.0
# 2020-05-11         82919.0  4633.0    78171.0
# 2020-05-12         82926.0  4633.0    78189.0
# 2020-05-13         82929.0  4633.0    78195.0
#
# [113 rows x 3 columns]

# %%
df_china.plot(figsize = (10,7), title="COVID-19")

# %%
import matplotlib.pyplot as plt

# %%
ax = df_mx.plot(figsize = (10,7), title="COVID-19 México", 
           legend = False,
           style = ['r-','g--','b:,'])
ax.legend(['Confirmados','Recuperados','Muertos'])
plt.xlabel('Periodo')
plt.ylabel('Personas')
plt.show()

# %%
df_monthly = df_mx.resample('M').max()
df_monthly
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-31             0.0     0.0        0.0
# 2020-02-29             4.0     0.0        0.0
# 2020-03-31          1094.0    28.0       35.0
# 2020-04-30         19224.0  1859.0    11423.0
# 2020-05-31         40186.0  4220.0    26990.0

# %%
df_monthly.plot(kind='bar', figsize = (10,7), stacked =True)

# %%
df_monthly['Traitment'] = df_monthly['Confirmed'] - df_monthly['Deaths'] -df_monthly['Recovered']
df_monthly
# Out:
#                  Confirmed  Deaths  Recovered  Traitment
# ObservationDate
# 2020-01-31             0.0     0.0        0.0        0.0
# 2020-02-29             4.0     0.0        0.0        4.0
# 2020-03-31          1094.0    28.0       35.0     1031.0
# 2020-04-30         19224.0  1859.0    11423.0     5942.0
# 2020-05-31         40186.0  4220.0    26990.0     8976.0

# %%
list(df_monthly)
# Out:
# ['Confirmed', 'Deaths', 'Recovered', 'Traitment']

# %%
df_monthly[['Deaths', 'Recovered', 'Traitment']].T.plot(figsize = (30,10), kind='pie', subplots=True, legend=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A06E2D8D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A06E31CD48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A06E34B588>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A06E5E08C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001A06E616C48>],
#       dtype=object)

# %%
df_mx
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-23             0.0     0.0        0.0
# 2020-02-28             1.0     0.0        0.0
# 2020-02-29             4.0     0.0        0.0
# 2020-03-01             5.0     0.0        0.0
# 2020-03-02             5.0     0.0        0.0
# ...                    ...     ...        ...
# 2020-05-09         33460.0  3353.0    21824.0
# 2020-05-10         35022.0  3465.0    21824.0
# 2020-05-11         36327.0  3573.0    23100.0
# 2020-05-12         38324.0  3926.0    25935.0
# 2020-05-13         40186.0  4220.0    26990.0
#
# [77 rows x 3 columns]

# %%
df_mx['rate'] = 1 - df_mx['Deaths'] / df_mx['Confirmed']
df_mx['rate'].hist(figsize=(10,7), bins=10)

# %%
df_mx['rate'].hist(figsize=(10,7), bins=10, density=True)

# %%
df_mx['rate'].plot(figsize=(10,7), kind='kde')
